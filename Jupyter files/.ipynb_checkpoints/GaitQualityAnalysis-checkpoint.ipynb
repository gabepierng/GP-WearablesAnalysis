# %%
# import os
import importlib
import cloudstorage as gcs
from google.cloud import storage
import pandas as pd

import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import scipy.interpolate as interp
import numpy as np
import math
import sys
import time
import re
import os
import random
# from control import get_control_data
import json
import scipy

from scipy import signal
import scipy.interpolate as interp

sys.path.append(os.path.join(sys.path[0], '..', 'src'))
# import excel_reader_gcp_dot as excel_reader
# import excel_reader_gcp as excel_reader
import excel_reader_gcp as excel_reader
import gait_metrics


# from random import shuffle
from dtw import dtw


plot_colors = ['black', 'red', 'orange', 'cyan', 'green', 'purple', 'blue']
use_manual_filenames = False

files = [
        ]

bucket_dir = 'gs://gaitbfb_propellab/'
# participants = ['LLA1', 'LLA2', 'LLA3', 'LLA4', 'LLA5', 'LLA6']
participants = ['AB1', 'LLA1', 'LLA2', 'LLA3', 'LLA4', 'LLA5', 'LLA6', 'LLA7', 'LLA8', 'LLA9', 'LLA10', 'LLA11', 'LLA12', 'LLA13']
# participant_dir =  os.path.join('Gait Quality Analysis/Data/Participant_Data/Processed Data/lla_xsens/PT Protocol Data/', participant, 'ExcelData')
control_dir = 'Gait Quality Analysis/Data/Participant_Data/Processed Data/AbleBodied_Control/CSV'

# print(participant_dir)

# df = pd.read_csv(participant_info)
# participants = df['Participant'].unique()

# fig, axs = plt.subplots(2)


part_strides = {}
part_gait_params = {}
part_kinematic_params = {}
control_strides = {}
control_gait_params = {}
control_kinematic_params = {}

temp_len = 0

partitioned_signals_dot = []
partitioned_signals_awinda_grouped = {}
target_SRs = []
nondesired_trial_nums = [4]
participant_of_interest = 14
orientation_tolerance = 10 # degrees
resize_len = 40
look_at_all_files = True
desired_filetypes = ['Baseline']
trials_accepted = 0
trials_total = 0

b20, a20 = scipy.signal.butter(N=4, Wn = 0.4, btype = 'lowpass')  # Wn = 0.2 = 10 / Nyquist F = 50Hz

signals_of_interest = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z']

# interpolate signal to convert to new frequency (for time aligning with xsens mvn system)
def convert_dot_freq(packetCount, downsampled_signal, old_freq=60, new_freq=100):
    x_o = np.array(packetCount)
    x_new = np.linspace(x_o[0], x_o[-1], int(x_o[-1] * (new_freq / old_freq)) )
    func_cubic = interp.interp1d(x_o, downsampled_signal, kind='cubic')
    y_new = func_cubic(x_new)
    return y_new

def reshape_vector(vectors_orig, new_size = 40, num_axes = 3):
    x_new = np.linspace(0, 100, new_size)
    trial_reshaped = []

    for stride in vectors_orig:
        # print(stride.shape)
        x_orig = np.linspace(0, 100, len(stride))
        func_cubic = [interp.interp1d(x_orig, stride[:,i], kind='cubic') for i in range(num_axes)]
        vec_cubic = np.array([func_cubic[i](x_new) for i in range(num_axes)]).transpose()
        trial_reshaped.append(vec_cubic)

    return np.array(trial_reshaped)

def combine_acc_and_gyro(numpy_acc, numpy_gyro):
    return np.concatenate((numpy_acc, numpy_gyro), axis=-1)

class AwindaData():
    def __init__(self, trial_type, partitioned_movement_data, gait_params = None):
        self.trial_type = trial_type
        self.partitioned_movement_data = partitioned_movement_data
        self.gait_params = gait_params

def compile_gait_data(store_gait_cycles, store_gait_params, store_kin_params, filenames, trial_type_filter, print_filenames=False, look_at_all_files = True, desired_filetypes=None):   
 
    XsensGaitParser = excel_reader.XsensGaitDataParser()  
    for i, file in enumerate(sorted(filenames)):
        trial_type = re.search(trial_type_filter, file).group(1)

        if(look_at_all_files or any(filetype in file for filetype in desired_filetypes)):
            XsensGaitParser.process_mvn_trial_data(os.path.join(bucket_dir, file), print_filenames)
            partitioned_mvn_data = XsensGaitParser.get_partitioned_mvn_data()
            gait_params = XsensGaitParser.get_gait_param_info()

            if trial_type in store_gait_cycles:
                for body_part in store_gait_cycles[trial_type]:
                    for i, side in enumerate(store_gait_cycles[trial_type][body_part]):
                        # for each part (pelvis, l_hip, r_knee, etc.), append strides to appropriate list
                        store_gait_cycles[trial_type][body_part][i] = store_gait_cycles[trial_type][body_part][i] + partitioned_mvn_data[body_part][i]

                store_gait_params[trial_type].append(gait_params['spatio_temp'])

                for joint in store_kin_params[trial_type]:
                    for i, side in enumerate(store_kin_params[trial_type][joint]):
                        store_kin_params[trial_type][joint][i] = np.append(store_kin_params[trial_type][joint][i], gait_params['kinematics'][joint][i], axis=0)

            else:
                store_gait_cycles[trial_type] = partitioned_mvn_data
                store_gait_params[trial_type] = [gait_params['spatio_temp']]
                store_kin_params[trial_type] = gait_params['kinematics']
        
##### READ AND STORE XSENS DATA #####
print('Importing participant data...')
client = storage.Client()
control_files = []   

for participant in participants:
    xsens_files = []
    if('AB' in participant):
        participant_dir =  os.path.join('Gait Quality Analysis/Data/Participant_Data/Raw Data/AB_BaselineWalking/', participant, 'CSV')
    else:
        participant_dir =  os.path.join('Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/', participant, 'CSV')
    print(participant_dir)
    for blob in client.list_blobs('gaitbfb_propellab', prefix=participant_dir):
        if ('.csv' in blob.name):
            xsens_files.append(blob.name)

    if('AB' in participant):
        compile_gait_data(part_strides, part_gait_params, part_kinematic_params, xsens_files, 'CSV/(.*?)_Baseline', False)
    else:
        # compile_gait_data(part_strides, part_gait_params, part_kinematic_params, xsens_files, 'ExcelData/(.*?)-00')
        compile_gait_data(part_strides, part_gait_params, part_kinematic_params, xsens_files, 'PT Protocol Data/(.*?)/CSV', True, False, ['Baseline'])

for blob in client.list_blobs('gaitbfb_propellab', prefix=control_dir):
    if('.csv' in blob.name):
        control_files.append(blob.name)
        
compile_gait_data(control_strides, control_gait_params, control_kinematic_params, control_files, 'CSV/(.*?)-00')
aggregate_control_data = {}

for i, indiv in enumerate(control_strides.keys()):
    indices = np.arange(len(control_strides[indiv]['gyro_data'][0]))
    np.random.shuffle(indices)
    
    if(i == 0):
        aggregate_control_data = control_strides[indiv]
        
        for signal_type in control_strides[indiv]:
            for j, side in enumerate(control_strides[indiv][signal_type]):
                if(len(indices) > 9):
                    aggregate_control_data[signal_type][j] = [control_strides[indiv][signal_type][j][indices[k]] for k in range(10)]
                else:
                    aggregate_control_data[signal_type][j] = [control_strides[indiv][signal_type][j][k] for k in indices]
    else:
        # choose 10 gait cycles randomly from each able-bodied participant, or all gait cycles if less than 10
        for signal_type in control_strides[indiv]:
            for j, side in enumerate(control_strides[indiv][signal_type]):
                if(len(indices) > 9):
                    aggregate_control_data[signal_type][j] = aggregate_control_data[signal_type][j] + [control_strides[indiv][signal_type][j][indices[k]] for k in range(10)]
                else:
                    aggregate_control_data[signal_type][j] = aggregate_control_data[signal_type][j] + [control_strides[indiv][signal_type][j][k] for k in indices]
                
    
    
####### WRITE CODE THAT CHOOSE X NUMBER OF GAIT CYCLES PER PERSON IN AB-CONTROL (OR ALL IF LESS THAN CHOSEN) ######
        
# print('Total trials taken: %d / %d' % (trials_accepted, trials_total))
partitioned_gait_data = []

# print(len(aggregate_control_data))

partitioned_awinda_control = {}
partitioned_awinda_control['Pelvis_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(aggregate_control_data['acc_data'][1]), reshape_vector(aggregate_control_data['gyro_data'][1]))
partitioned_awinda_control['UpperR_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(aggregate_control_data['acc_data'][2]), reshape_vector(aggregate_control_data['gyro_data'][2]))
partitioned_awinda_control['UpperL_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(aggregate_control_data['acc_data'][5]), reshape_vector(aggregate_control_data['gyro_data'][5]))
partitioned_awinda_control['LowerR_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(aggregate_control_data['acc_data'][3]), reshape_vector(aggregate_control_data['gyro_data'][3]))
partitioned_awinda_control['LowerL_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(aggregate_control_data['acc_data'][6]), reshape_vector(aggregate_control_data['gyro_data'][6]))

partitioned_awinda_control['pelvis_orient'] = reshape_vector(aggregate_control_data['pelvis_orient'][0], new_size = 51)
partitioned_awinda_control['hip_angle'] = [reshape_vector(aggregate_control_data['hip_angle'][0], new_size = 51), reshape_vector(aggregate_control_data['hip_angle'][1], new_size = 51)]
partitioned_awinda_control['knee_angle'] = [reshape_vector(aggregate_control_data['knee_angle'][0], new_size = 51), reshape_vector(aggregate_control_data['knee_angle'][1], new_size = 51)]
partitioned_awinda_control['ankle_angle'] = [reshape_vector(aggregate_control_data['ankle_angle'][0], new_size = 51), reshape_vector(aggregate_control_data['ankle_angle'][1], new_size = 51)]

partitioned_gait_data.append(AwindaData('control', partitioned_awinda_control))

for trial_type in part_strides.keys():
    partitioned_signals_awinda_grouped = {}
    partitioned_signals_awinda_grouped['Pelvis_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(part_strides[trial_type]['acc_data'][1]), reshape_vector(part_strides[trial_type]['gyro_data'][1]))
    partitioned_signals_awinda_grouped['UpperR_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(part_strides[trial_type]['acc_data'][2]), reshape_vector(part_strides[trial_type]['gyro_data'][2]))
    partitioned_signals_awinda_grouped['UpperL_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(part_strides[trial_type]['acc_data'][5]), reshape_vector(part_strides[trial_type]['gyro_data'][5]))
    partitioned_signals_awinda_grouped['LowerR_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(part_strides[trial_type]['acc_data'][3]), reshape_vector(part_strides[trial_type]['gyro_data'][3]))
    partitioned_signals_awinda_grouped['LowerL_IMU'] = combine_acc_and_gyro(0.02*reshape_vector(part_strides[trial_type]['acc_data'][6]), reshape_vector(part_strides[trial_type]['gyro_data'][6]))
    
    partitioned_signals_awinda_grouped['pelvis_orient'] = reshape_vector(part_strides[trial_type]['pelvis_orient'][0], new_size = 51)
    partitioned_signals_awinda_grouped['hip_angle'] = [reshape_vector(part_strides[trial_type]['hip_angle'][0], new_size = 51), 
                                                       reshape_vector(part_strides[trial_type]['hip_angle'][1], new_size = 51)]
    partitioned_signals_awinda_grouped['knee_angle'] = [reshape_vector(part_strides[trial_type]['knee_angle'][0], new_size = 51), 
                                                        reshape_vector(part_strides[trial_type]['knee_angle'][1], new_size = 51)]
    partitioned_signals_awinda_grouped['ankle_angle'] = [reshape_vector(part_strides[trial_type]['ankle_angle'][0], new_size = 51), 
                                                         reshape_vector(part_strides[trial_type]['ankle_angle'][1], new_size = 51)]
    
    partitioned_gait_data.append(AwindaData(trial_type, partitioned_signals_awinda_grouped, part_gait_params[trial_type]))
# excel_reader.visualize_strides(xsens_dot_partitioned_by_ge_baseline[:,:,3:], ax1, 0, 0)

for gait_data_set in partitioned_gait_data:
    if not(gait_data_set.gait_params is None):
        stance_time_symmetry = [item for sublist in [i[11] for i in gait_data_set.gait_params] for item in sublist]
        knee_ROMs = [item for sublist in [i[12] for i in gait_data_set.gait_params] for item in sublist]
        knee_ROMs_R_flex = [i[0,2] for i in knee_ROMs]
        knee_ROMs_L_flex = [i[1,2] for i in knee_ROMs]
        hip_ROMs = [item for sublist in [i[13] for i in gait_data_set.gait_params] for item in sublist]
        hip_ROMs_R_flex = [i[0,2] for i in hip_ROMs]
        hip_ROMs_L_flex = [i[1,2] for i in hip_ROMs]

        # print(len(knee_ROMs_R_flex))
        step_lengths_R = [item for sublist in [i[9][0] for i in gait_data_set.gait_params] for item in sublist]
        step_lengths_L = [item for sublist in [i[9][1] for i in gait_data_set.gait_params] for item in sublist]
        stride_lengths = [item for sublist in [i[14][0] for i in gait_data_set.gait_params] for item in sublist]
        speed = [item for sublist in [i[15] for i in gait_data_set.gait_params] for item in sublist]
        cadence = [item for sublist in [i[16] for i in gait_data_set.gait_params] for item in sublist]

        print()
        print(gait_data_set.trial_type)
        print('Num strides: ', len(stance_time_symmetry))
        print('Mean Speed: %.3f ± %.3f' % (np.mean(speed), np.std(speed)))
        print('Mean Cadence: %.3f ± %.3f' % (np.mean(cadence), np.std(cadence)))
        print('')

        print()
        print('Mean symmetry: %.3f ± %.3f' % (np.mean(stance_time_symmetry), np.std(stance_time_symmetry)))
        print('Upper 95% of the data: ', sorted(stance_time_symmetry)[round(0.95 * len(stance_time_symmetry))])
        print('Lower 95% of the data: ', sorted(stance_time_symmetry)[round(0.05 * len(stance_time_symmetry))])
        print()

        # for i, symmetries in enumerate(training_symmetries):
        #     # print(len(symmetries))
        #     # print(len(partitioned_signals_dot[i]['LowerR']))
        #     y = (np.ones(len(symmetries)) * target_SRs[i]) + np.random.normal(0,  0.02, len(symmetries))
        #     plt.scatter(symmetr, y, s = 6)

        # plt.show()
        # plt.figure()
        # y = (np.ones(len(stance_time_symmetry))) + np.random.normal(0, 0.02, len(stance_time_symmetry))
        # plt.hist(stance_time_symmetry, bins = 25)

        # if(ab_or_llpu == 'AB'):
        #     plt.xlim([0.7, 1.10])
        # else:
        #     plt.xlim([0.8, 1.2])

#         plt.figure(figsize = (10, 4))

#         y = (np.zeros(len(stance_time_symmetry))) + np.random.normal(0,  0.02, len(stance_time_symmetry))
#         plt.scatter(stance_time_symmetry, y, s = 6, color='black')

#         # if(ab_or_llpu == 'AB'):
#         #     plt.xlim([0.8, 1.13])
#         # else:
#         #     plt.xlim([0.8, 1.2])

#         plt.ylim([-0.2, 0.2])
#         ax_set = plt.gca()
#         ax_set.get_yaxis().set_visible(False)

#         plt.xlabel('Stance Time Symmetry Ratio', fontsize = 14)
#         plt.show()

# fig, axs = plt.subplots(2)
# excel_reader.visualize_strides(partitioned_signals_dot[0]['LowerL'][:,:,5], axs[0], 0, 0)
# excel_reader.visualize_strides(partitioned_signals_dot[1]['LowerL'][:,:,5], axs[0], 0, 1)
# excel_reader.visualize_strides(partitioned_signals_dot[2]['LowerL'][:,:,5], axs[0], 0, 2)
# # excel_reader.visualize_strides(partitioned_signals_dot[3]['LowerL'][:,:,5], axs[0], 0, 3)

# excel_reader.visualize_strides(partitioned_signals_dot[0]['LowerR'][:,:,5], axs[1], 0, 0)
# excel_reader.visualize_strides(partitioned_signals_dot[1]['LowerR'][:,:,5], axs[1], 0, 1)
# excel_reader.visualize_strides(partitioned_signals_dot[2]['LowerR'][:,:,5], axs[1], 0, 2)
# # excel_reader.visualize_strides(partitioned_signals_dot[3]['LowerR'][:,:,5], axs[1], 0, 3)
# plt.show()
# Out:
# Importing participant data...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/AB_BaselineWalking/AB1/CSV
# Gait Quality Analysis/Data/Participant_Data/Raw Data/AB_BaselineWalking/AB2/CSV
# Gait Quality Analysis/Data/Participant_Data/Raw Data/AB_BaselineWalking/AB4/CSV
# Gait Quality Analysis/Data/Participant_Data/Raw Data/AB_BaselineWalking/AB10/CSV
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-00110_94-612G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-00111G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-00112G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0011G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0011H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0012G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0012H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0013G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0013_86-1855H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0014G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0014_8-655H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0014_832-2285H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0015G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0015H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0016H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0016_74-809G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0017H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0017_120-975G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0018H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0018_117-869G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0019G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-00210_101-767G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0021_4-720G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0022G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0023_70-767G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0024G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0025_80-755G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0026G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0027_20-658G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0028G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA1/CSV/Baseline-0029_116-735G.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_11023-12178H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_1113-1757G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_12178-12831H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_12953-13972H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_14051-14802H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_14924-16759H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_16895-18214H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_1859-2613G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_18981-20089H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_20298-21134H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_2338-4268H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_243-974G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_259-2202H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_2713-3450G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_3593-4322G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_4486-5256G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_5180-6058H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_5413-6190G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_6097-6850H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_6333-7131G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_7104-8793H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_7240-8010G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_8214-8869G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_8889-10860H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_9108-9714G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA2/CSV/Baseline-001_9850-10614G.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0011G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0011H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0012G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0012H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0013G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0013H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0014G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0014H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0015G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0016G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0017G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0018G.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-00210H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0021H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0022H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0023H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0024H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0025H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0026H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0027H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0028H.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA3/CSV/Baseline-0029H.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_11054-11602.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_11827-12492.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_12724-13335.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_1301-1825.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_13782-14260.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_14682-15276.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_15631-16134.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_16396-16934.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_17113-17792.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_18179-18685.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_18924-19448.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_2184-2623.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_2965-3545.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_3816-4424.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_454-995.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_4650-5304.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_5721-6234.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_6575-7082.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_7379-7949.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_8149-8807.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_9123-9700.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-001_9927-10546.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_10203-10949.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_11105-11812.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_11931-12654.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_12888-13621.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_13774-14512.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_14641-15425.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_15496-16179.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_16246-16904.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_17029-17646.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_17838-18509.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_18659-19271.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_5154-5759.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_5979-6659.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_6722-7480.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_7781-8411.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_8-1014.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_8552-9369.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA4/CSV/Baseline-002_9507-10111.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_10494-11118.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_1051-1736.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_11253-11868.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_12012-12763.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_13564-14227.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_14448-14931.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_16021-16386.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_2001-2560.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_2560-3192.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_3266-3779.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_3835-4464.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_394-1037.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_5208-5816.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_5873-6558.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_6618-7258.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_7438-7940.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_8067-8792.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-001_9689-10312.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_11344-11933.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_1194-1736.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_12986-13691.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_13739-14436.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_14725-15416.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_15717-16271.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_16616-17057.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_1760-2469.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_18140-18592.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_18724-19356.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_249-982.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_2658-3298.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_3496-4043.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_4383-4837.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_5066-5697.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_6023-6595.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_6858-7471.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_7874-8500.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_8707-9354.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA5/CSV/Baseline-002_9520-10316.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_10050-11416.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_11607-13221.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_13387-14910.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_15270-16646.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_16836-18550.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_3228-4828.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_5013-6409.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_6706-8093.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA6/CSV/Baseline-001_8330-9825.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_1489-2334.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_201-1238.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_2460-3296_102-836.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_3422-4383.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_6633-7277.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_8699-9435.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-001_9787-10707.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-002_11228-12094.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-002_265-1193_129-569.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-002_4636-5563.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-002_8019-8864_2-677.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-002_9058-10056_1-901_117-852.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_2282-3046.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_3280-4004.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_4146-4971.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_551-1233.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_6937-7742.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_7884-8598.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA7/CSV/Baseline-003_8750-9677.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_13120-14589.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_2005-3301.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_346-1808.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_3478-4785.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_4987-6258.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_6445-7901.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_8115-9446.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-001_9728-11257.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-002_1530-2808.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-002_3170-4511.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-002_4753-6094.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-002_6353-7626.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-004_3188-4610.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-004_4888-6123.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA8/CSV/Baseline-006_11544-12576_37-646.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_15213-16141.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_16502-17481.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_1685-2716_181-1031.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_20524-21469.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_21727-22758_280-1031.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_224-1255.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_2940-3988.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-001_8440-9403.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_10977-11957.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_13705-14728.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_20418-21377.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_25831-26684.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_27110-28069.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_3027-4029.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA9/CSV/Baseline-002_320-1301.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-001_3700-5030.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-001_7024-8303.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-001_88-1531.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_11480-12777.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_13209-14430.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_14806-15990.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_18150-19297.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_19785-21044.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_21551-22716.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_23186-24557.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_3683-4904.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_395-1691.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_5299-6389.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-002_8343-9357.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_11266-12549.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_13021-14417.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_18285-19550.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_20002-21437.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_2208-3680.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_23569-24965.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_4001-5397.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_5794-7209.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA10/CSV/Baseline-003_709-1817.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_18189-19214.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_19649-20768.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_3387-4365.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_6384-7549.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_715-1647.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-001_9351-10532.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-002_11751-12820.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-002_13157-14124.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-002_17245-18285.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-002_2125-3297.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-002_9026-10007.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-Running-001_113-617.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-Running-001_6632-7369.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA11/CSV/Baseline-Running-002_3208-3913_357-705.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_10776-11834.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_12214-13408.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_13897-14982.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_15525-16611.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_17072-18049.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_1792-2796.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_18538-19569.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_19976-21008.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_21442-22419.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_23043-24020.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_24509-25540.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_25947-27060.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_27576-28662.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_29204-30127.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_30561-31701.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_32054-33140.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_3257-4235.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_33656-34768.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_4615-5619.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_6053-7003.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_7519-8713.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_82-1330.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA12/CSV/Baseline-001_9093-10287.csv'...
# Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_11149-12115.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_15246-16387.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_16650-17645.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_17996-19108.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_20805-21771.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_22034-23146.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_23439-24434.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_24843-25809.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_28881-29935_41-1045.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_30432-31251_48-819.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_31661-32832.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_34675-35524_43-849.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_35962-36957.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_37338-38186_31-848.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_4390-5414.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_498-1434.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_5706-6584.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_6906-7960.csv'...
# Parsed file 'gs://gaitbfb_propellab/Gait Quality Analysis/Data/Participant_Data/Raw Data/LLA_xsens/PT Protocol Data/LLA13/CSV/Baseline-001_9657-10769.csv'...
#
# P01
# Num strides:  45
# Mean Speed: 1.688 ± 0.056
# Mean Cadence: 117.885 ± 2.576
#
#
# Mean symmetry: 0.999 ± 0.036
# Upper 95% of the data:  1.103448275862069
# Lower 95% of the data:  0.9649122807017544
#
#
# AB_P02
# Num strides:  49
# Mean Speed: 1.491 ± 0.086
# Mean Cadence: 117.723 ± 2.480
#
#
# Mean symmetry: 1.020 ± 0.023
# Upper 95% of the data:  1.0555555555555556
# Lower 95% of the data:  0.9830508474576272
#
#
# AB_P04
# Num strides:  49
# Mean Speed: 1.533 ± 0.099
# Mean Cadence: 119.733 ± 3.441
#
#
# Mean symmetry: 0.978 ± 0.028
# Upper 95% of the data:  1.0188679245283019
# Lower 95% of the data:  0.9298245614035088
#
#
# AB10
# Num strides:  166
# Mean Speed: 1.175 ± 0.060
# Mean Cadence: 98.367 ± 2.312
#
#
# Mean symmetry: 0.991 ± 0.031
# Upper 95% of the data:  1.0441176470588236
# Lower 95% of the data:  0.9342105263157895
#
#
# LLA1
# Num strides:  176
# Mean Speed: 0.895 ± 0.121
# Mean Cadence: 85.461 ± 7.573
#
#
# Mean symmetry: 1.183 ± 0.081
# Upper 95% of the data:  1.329268292682927
# Lower 95% of the data:  1.0632911392405062
#
#
# LLA2
# Num strides:  148
# Mean Speed: 1.055 ± 0.066
# Mean Cadence: 89.293 ± 2.545
#
#
# Mean symmetry: 1.246 ± 0.047
# Upper 95% of the data:  1.3492063492063493
# Lower 95% of the data:  1.1857142857142857
#
#
# LLA3
# Num strides:  225
# Mean Speed: 0.640 ± 0.106
# Mean Cadence: 70.675 ± 3.753
#
#
# Mean symmetry: 1.129 ± 0.053
# Upper 95% of the data:  1.2156862745098038
# Lower 95% of the data:  1.0380952380952382
#
#
# LLA4
# Num strides:  160
# Mean Speed: 1.239 ± 0.090
# Mean Cadence: 113.508 ± 5.194
#
#
# Mean symmetry: 1.023 ± 0.065
# Upper 95% of the data:  1.1454545454545455
# Lower 95% of the data:  0.9242424242424242
#
#
# LLA5
# Num strides:  139
# Mean Speed: 1.110 ± 0.096
# Mean Cadence: 113.040 ± 6.310
#
#
# Mean symmetry: 0.973 ± 0.073
# Upper 95% of the data:  1.106060606060606
# Lower 95% of the data:  0.8787878787878788
#
#
# LLA6
# Num strides:  86
# Mean Speed: 1.150 ± 0.071
# Mean Cadence: 97.978 ± 2.839
#
#
# Mean symmetry: 1.083 ± 0.037
# Upper 95% of the data:  1.1515151515151516
# Lower 95% of the data:  1.0149253731343284
#
#
# LLA7
# Num strides:  75
# Mean Speed: 1.047 ± 0.116
# Mean Cadence: 100.778 ± 5.709
#
#
# Mean symmetry: 1.130 ± 0.050
# Upper 95% of the data:  1.2205882352941178
# Lower 95% of the data:  1.0579710144927537
#
#
# LLA8
# Num strides:  158
# Mean Speed: 0.973 ± 0.073
# Mean Cadence: 115.616 ± 3.923
#
#
# Mean symmetry: 1.002 ± 0.033
# Upper 95% of the data:  1.0535714285714286
# Lower 95% of the data:  0.9552238805970149
#
#
# LLA9
# Num strides:  100
# Mean Speed: 1.146 ± 0.048
# Mean Cadence: 106.336 ± 2.460
#
#
# Mean symmetry: 0.956 ± 0.034
# Upper 95% of the data:  1.015625
# Lower 95% of the data:  0.9104477611940298
#
#
# LLA10
# Num strides:  179
# Mean Speed: 0.905 ± 0.082
# Mean Cadence: 90.911 ± 5.590
#
#
# Mean symmetry: 0.876 ± 0.078
# Upper 95% of the data:  0.9880952380952381
# Lower 95% of the data:  0.7959183673469388
#
#
# LLA11
# Num strides:  95
# Mean Speed: 1.284 ± 0.319
# Mean Cadence: 105.956 ± 9.344
#
#
# Mean symmetry: 0.894 ± 0.076
# Upper 95% of the data:  0.9852941176470589
# Lower 95% of the data:  0.7090909090909091
#
#
# LLA12
# Num strides:  178
# Mean Speed: 1.148 ± 0.079
# Mean Cadence: 108.301 ± 4.086
#
#
# Mean symmetry: 1.169 ± 0.040
# Upper 95% of the data:  1.2352941176470589
# Lower 95% of the data:  1.1129032258064515
#
#
# LLA13
# Num strides:  143
# Mean Speed: 1.310 ± 0.071
# Mean Cadence: 111.236 ± 3.282
#
#
# Mean symmetry: 0.980 ± 0.036
# Upper 95% of the data:  1.0526315789473684
# Lower 95% of the data:  0.921875

# %%
import gait_metrics

plot_axis = 4
fig, axs = plt.subplots(2)
plot_part = ['AB_P4', 'control']
for i, gait_data_set in enumerate(partitioned_gait_data):
    # if(gait_data_set.trial_type in plot_part):
    if(True):
        print(gait_data_set.trial_type)
        # print(gait_data_set.partitioned_movement_data['LowerL_IMU'].shape)
        # excel_reader.visualize_strides(gait_data_set.partitioned_movement_data['UpperR_IMU'][:,:,plot_axis], axs[0], 0, i)
        gait_profile_score = gait_metrics.calc_gait_profile_score(gait_data_set.partitioned_movement_data, partitioned_gait_data[0].partitioned_movement_data)
        print('Gait Profile Score: %.3f' % (gait_profile_score))
        print()
    
# fig, axs = plt.subplots(2)
plot_axis = 2
excel_reader.visualize_strides(partitioned_gait_data[1].partitioned_movement_data['knee_angle'][0][:,:,plot_axis], axs[1], 0, 0)
excel_reader.visualize_strides(partitioned_gait_data[1].partitioned_movement_data['knee_angle'][1][:,:,plot_axis], axs[1], 0, 1)


gait_profile_score = gait_metrics.calc_gait_profile_score(partitioned_gait_data[1].partitioned_movement_data, partitioned_gait_data[0].partitioned_movement_data)

# print(gait_profile_score)
# print(partitioned_awinda_control['LowerL'].shape)
# excel_reader.visualize_strides(partitioned_awinda_control['UpperR'][:,:,plot_axis], axs[0], 0, 5)
# excel_reader.visualize_strides(partitioned_signals_dot[0]['UpperL'][:,:,5], axs[0], 0, 0)
# excel_reader.visualize_strides(partitioned_signals_dot[1]['UpperL'][:,:,5], axs[0], 0, 1)
# excel_reader.visualize_strides(partitioned_signals_dot[2]['UpperL'][:,:,5], axs[0], 0, 2)
# # excel_reader.visualize_strides(partitioned_signals_dot[3]['LowerL'][:,:,5], axs[0], 0, 3)

# excel_reader.visualize_strides(partitioned_signals_dot[0]['UpperR'][:,:,5], axs[1], 0, 0)
# excel_reader.visualize_strides(partitioned_signals_dot[1]['UpperR'][:,:,5], axs[1], 0, 1)
# excel_reader.visualize_strides(partitioned_signals_dot[2]['UpperR'][:,:,5], axs[1], 0, 2)

# plt.show()
# Out:
# control
# Gait Profile Score: 0.000
#
# P01
# Gait Profile Score: 4.632
#
# AB_P02
# Gait Profile Score: 4.017
#
# AB_P04
# Gait Profile Score: 3.436
#
# AB10
# Gait Profile Score: 3.572
#
# LLA1
# Gait Profile Score: 7.608
#
# LLA2
# Gait Profile Score: 9.097
#
# LLA3
# Gait Profile Score: 8.909
#
# LLA4
# Gait Profile Score: 5.056
#
# LLA5
# Gait Profile Score: 10.022
#
# LLA6
# Gait Profile Score: 5.709
#
# LLA7
# Gait Profile Score: 10.490
#
# LLA8
# Gait Profile Score: 6.041
#
# LLA9
# Gait Profile Score: 5.760
#
# LLA10
# Gait Profile Score: 9.111
#
# LLA11
# Gait Profile Score: 6.431
#
# LLA12
# Gait Profile Score: 5.829
#
# LLA13
# Gait Profile Score: 5.384
#
# Mean standard deviation: 2.0361
# Mean standard deviation: 1.8321

# %%
import seaborn as sns
max_size = 0

sym_range_strides = {}
symmetry_split_into_ranges = []
sym_strides_to_add = [ [] for _ in range(len(sym_ranges))]
# print((xsens_dot_partitioned_by_ge[0].shape))
for i in range(len(stance_time_symmetry)):
    for j in range(len(sym_ranges)):
        if((stance_time_symmetry[i] > sym_ranges[j][0]) and (stance_time_symmetry[i] < sym_ranges[j][1])):
            sym_strides_to_add[j].append(i)
            break
        
trial_types = []
strides_used_for_training = 0
for i in range(len(sym_ranges)):
    symmetry_split_into_ranges.append( np.array([stance_time_symmetry[k] for k in sym_strides_to_add[i]]) )
    trial_types.append('Avg. Sym - ' + str( np.round( np.mean(symmetry_split_into_ranges[-1]), 3) ) )
    sym_range_strides[trial_types[-1]] = {}
    for sensor in sensor_locs:
        sym_range_strides[trial_types[-1]][sensor] = partitioned_signals_dot_grouped[sensor][sym_strides_to_add[i]]
    print('Number of strides in %s: %d' % (trial_types[-1], len(sym_range_strides[trial_types[-1]]['Pelvis'])))
    strides_used_for_training = strides_used_for_training + len(sym_range_strides[trial_types[-1]]['Pelvis'])
    
print('Total strides used for training: ', strides_used_for_training)
for i, symmetries in enumerate(symmetry_split_into_ranges):
    y = (np.ones(len(symmetries)) * np.mean(symmetries)) + np.random.normal(0,  0.02, len(symmetries))
    plt.scatter(symmetries, y, s = 6)
    
plt.title('Target Symmetry vs. Actual Symmetry (%s-%d)' % (ab_or_llpu, participant_of_interest))
plt.xlabel('Actual Symmetry')
plt.ylabel('Target Symmetry')
plt.legend(trial_types)
plt.show()
    

fig, axs = plt.subplots(2)
plt_axis = 2
print(sym_range_strides[trial_types[0]].keys())
excel_reader.visualize_strides(sym_range_strides[trial_types[0]]['UpperR'][:,:,plt_axis], axs[0], 0, 0)
excel_reader.visualize_strides(sym_range_strides[trial_types[1]]['UpperR'][:,:,plt_axis], axs[0], 0, 1)
# excel_reader.visualize_strides(sym_range_strides[trial_types[2]]['Pelvis'][:,:,plt_axis], axs[0], 0, 2)

print(sym_range_strides[trial_types[1]]['Pelvis'][:,:,0:].shape)
# excel_reader.visualize_strides(partitioned_signals_dot[3]['LowerL'][:,:,plt_axis], axs[0], 0, 3)

excel_reader.visualize_strides(sym_range_strides[trial_types[0]]['LowerL'][:,:,plt_axis], axs[1], 0, 0)
excel_reader.visualize_strides(sym_range_strides[trial_types[1]]['LowerL'][:,:,plt_axis], axs[1], 0, 1)
# excel_reader.visualize_strides(sym_range_strides[trial_types[2]]['LowerR'][:,:,plt_axis], axs[1], 0, 2)
# excel_reader.visualize_strides(partitioned_signals_dot[3]['LowerR'][:,:,plt_axis], axs[1], 0, 3)
plt.show()

plt.figure(figsize = (11,7))
plt.hist(stance_time_symmetry, bins = 15, density=False, rwidth=0.9, color='black', alpha = 0.6)
plt.xlabel('Stance-Time Symmetry', fontsize=16)
plt.ylabel('Number of Strides', fontsize=16)
plt.title('Example Symmetry Distribution', fontsize=18)
# plt.range()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/tmp/ipykernel_8324/1095864641.py in <module>
#      18     trial_types.append('Avg. Sym - ' + str( np.round( np.mean(symmetry_split_into_ranges[-1]), 3) ) )
#      19     sym_range_strides[trial_types[-1]] = {}
# ---> 20     for sensor in sensor_locs:
#      21         sym_range_strides[trial_types[-1]][sensor] = partitioned_signals_dot_grouped[sensor][sym_strides_to_add[i]]
#      22     print('Number of strides in %s: %d' % (trial_types[-1], len(sym_range_strides[trial_types[-1]]['Pelvis'])))
#
# NameError: name 'sensor_locs' is not defined

# %%
# TRAINING 3 SYMMETRY LEVELS, NO SPLITTING OF THE STRIDES IN THE SYMMETRY RANGES

from hmmlearn import hmm
import seaborn as sns

partitioned_strides = {}
trial_types = []
for i, gait_data_set in enumerate(partitioned_gait_data):
    trial_type = gait_data_set.trial_type
    trial_types.append(trial_type)
    # partitioned_strides[trial_type] = gait_data_set.partitioned_movement_data['Pelvis_IMU'][:,:,0:]
    partitioned_strides[trial_type] = np.concatenate([gait_data_set.partitioned_movement_data['UpperR_IMU'][:,:,3:], 
                                                      gait_data_set.partitioned_movement_data['UpperL_IMU'][:,:,3:]], axis=2)
    np.random.shuffle(partitioned_strides[trial_type])
    print('Number of %s strides: %d' % (trial_type, len(partitioned_strides[trial_type])))
# pre_strides = partitioned_signals_dot['Pre']['LowerL'][:,:,3:]
# post_strides = partitioned_signals_dot['PostRehab']['LowerL'][:,:,3:]
# cr_strides = partitioned_signals_dot['CueingRemoved']['LowerL'][:,:,3:]
print()
# concatenate multiple strides together. Done in a "sliding window" over gait cycles, to still have reasonable amount of training samples

concat_strides = {}
strides_to_concat = 4

for trial_type in trial_types:
    concat_strides[trial_type] = []
    for i in range(partitioned_strides[trial_type].shape[0] - strides_to_concat):
        temp = []
        for j in range(strides_to_concat):
            temp.append(partitioned_strides[trial_type][i + j])

        concat_strides[trial_type].append(np.concatenate(temp, axis=0))
    
    concat_strides[trial_type] = np.array(concat_strides[trial_type])
    concat_strides[trial_type] = signal.filtfilt(b20, a20, concat_strides[trial_type], axis=1)
    
# for i in range(3,8):
#     plt.figure(figsize=(8, 3))
#     for j in range(6):
#         x = concat_strides[trial_types[2]][0, :, j]
#         if(j < 3):
#             x = x * 3
            
#         if(j < 5):
#             plt.plot(x, 'k', alpha=0.3)
#         else:
#             plt.plot(x, 'k')
#     # plt.plot(concat_strides[trial_types[0]][20, :, 5])
#     plt.show()
# Out:
# Number of control strides: 291
# Number of P01 strides: 45
# Number of AB_P02 strides: 49
# Number of AB_P04 strides: 49
# Number of AB10 strides: 166
# Number of LLA1 strides: 176
# Number of LLA2 strides: 148
# Number of LLA3 strides: 225
# Number of LLA4 strides: 160
# Number of LLA5 strides: 139
# Number of LLA6 strides: 86
# Number of LLA7 strides: 75
# Number of LLA8 strides: 158
# Number of LLA9 strides: 100
# Number of LLA10 strides: 179
# Number of LLA11 strides: 95
# Number of LLA12 strides: 178
# Number of LLA13 strides: 143

# %%
# for i in range(pre_strides.shape[0] - strides_to_concat):
#     temp = []
#     for j in range(strides_to_concat):
#         temp.append(pre_strides[i + j])
        
#     pre_strides_concat.append(np.concatenate(temp, axis=0))
    
# for i in range(post_strides.shape[0] - strides_to_concat):
#     temp = []
#     for j in range(strides_to_concat):
#         temp.append(post_strides[i + j])
        
#     post_strides_concat.append(np.concatenate(temp, axis=0))

# pre_strides_concat = np.array(pre_strides_concat)
# post_strides_concat = np.array(post_strides_concat)


# pre_strides_concat = signal.filtfilt(b20, a20, pre_strides_concat, axis=1)
# post_strides_concat = signal.filtfilt(b20, a20, post_strides_concat, axis=1)

class HMMTrainer(object):
    def __init__(self, model_name='GaussianHMM', n_components=4, cov_type='full', n_iter=50, tolerance = 0.005):
        self.model_name = model_name
        self.n_components = n_components
        self.cov_type = cov_type
        self.n_iter = n_iter
        self.models = []
        if self.model_name == 'GaussianHMM':
            # self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='stmc', verbose=False)
            self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='mc', verbose=False)
            self.model.transmat_ = np.zeros((n_components, n_components))
            for i in range(n_components):
                self.model.transmat_[i, 0:2] = np.random.dirichlet(np.ones(2)/1.5, size=1)
                self.model.transmat_[i, 2:] = np.random.dirichlet(np.ones(self.n_components - 2), size=1)[0] / 1e80
                self.model.transmat_[i] = np.roll(self.model.transmat_[i], i)

        else:
            raise TypeError('Invalid model type') 

    # resize_len = num_samples
    def train(self, X, resize_len, num_sequences):
        np.seterr(all='ignore')
        
        self.model.fit(X, lengths=resize_len * np.ones(num_sequences, dtype=int))
        # x_concat = np.concatenate(X).reshape(-1,1)
        # self.models.append(self.model.fit(X))
        # self.models.append(self.model.fit(x_concat, lengths = [X.shape[1] for i in range(X.shape[0])]))
        # Run the model on input data
    def get_score(self, input_data):
        return self.model.score(input_data)
        # return self.model.score(input_data.reshape(-1,1))

strides_train_flat = {}
strides_test_flat = {}
strides_train = {}
strides_test = {}

# pre_strides_test_flat = []
# post_strides_test_flat = []
# cr_strides_test_flat = []

num_states=3
train_iterations = 300
train_tolerance = 0.01

hmm_models = {}
num_models_train = 10

for trial_type in trial_types:
    print('Training %s models...' % (trial_type))
    hmm_models[trial_type] = []
    
    for j in range(num_models_train):
        train_forward_model = True
        k = 0

        while(train_forward_model):
            print('Train Attempt ', k+1, end="\r", flush=True)
            if(j > -1):
                np.random.shuffle(concat_strides[trial_type])
            strides_sequence_flattened = concat_strides[trial_type].reshape((concat_strides[trial_type].shape[0] * concat_strides[trial_type].shape[1], -1))
            len_train = int(0.95 * len(concat_strides[trial_type]))
            strides_train[trial_type] = concat_strides[trial_type][:len_train]
            strides_test[trial_type] = concat_strides[trial_type][len_train:]
            sequence_length = resize_len * strides_to_concat
            strides_train_flat[trial_type] = strides_sequence_flattened[:sequence_length * len_train]
            strides_test_flat[trial_type] = strides_sequence_flattened[sequence_length * len_train:]

            hmm_model = HMMTrainer(n_components = num_states, n_iter = train_iterations, tolerance = train_tolerance)
            hmm_model.train(strides_train_flat[trial_type], sequence_length, len_train)

            valid_rows = 0
            a_mat = hmm_model.model.transmat_
            for i, row in enumerate(a_mat):
                temp = np.argpartition(np.roll(row, -i), -2)[-2:]
                if((np.array(temp) == np.array([0,1])).all() or (np.array(temp) == np.array([1,0])).all()):
                    valid_rows = valid_rows + 1
            
            # correct_second_state = [i for i in range(num_states - 1)]
            # correct_second_state.append(0)
            # valid_rows = 0
            # for i, row in enumerate(hmm_model.model.transmat_):
            #     max_state = np.argmax(row)
            #     if(max_state == i):
            #         temp = [j for j in row if not (j == row[max_state])]
            #         if(np.argmax(temp) == correct_second_state[i]):
            #             valid_rows = valid_rows + 1

            if(valid_rows == num_states):
                train_forward_model = False
            k = k + 1

        print()
        hmm_models[trial_type].append(hmm_model)
    
print('done')
# print(len(pre_strides))
# print(len(post_strides))

# num_classified_pre = 0
# num_classified_post = 0

# print('Number of test strides: ', len(partitioned_strides[trial_types[0]]))
# for stride_test in partitioned_strides[trial_types[0]]:
#     score_label = []
#     # max_score = -99999999999999999
#     output_label = None
    
#     # score_pre = hmm_pre.get_score(stride_test)
#     score_pre = hmm_models[trial_types[0]][0].get_score(stride_test)
#     score_post = hmm_models[trial_types[2]][0].get_score(stride_test)
    
#     if(score_pre > score_post):
#         num_classified_pre = num_classified_pre + 1
#     elif(score_post > score_pre):
#         num_classified_post = num_classified_post + 1
    
# print('Accuracy: %.4f' % ( 100 * (num_classified_post / len(partitioned_strides[trial_types[0]])) ))

# sns.heatmap(hmm_models[trial_types[0]][0].model.transmat_)
# plt.figure()
# sns.heatmap(hmm_models[trial_types[2]][0].model.transmat_)


# for spec_model in hmm_models[trial_types[0]]:
#     print(spec_model.model.transmat_)
#     plt.figure()
#     sns.heatmap(spec_model.model.transmat_)
# Out:
# Training control models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training P01 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training AB_P02 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  4
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  3
# Train Attempt  1
# Train Attempt  2
# Training AB_P04 models...
# Train Attempt  2
# Train Attempt  3
# Train Attempt  1
# Train Attempt  1
# Train Attempt  3
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Training AB10 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA1 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  3
# Train Attempt  2
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  4
# Train Attempt  2
# Training LLA2 models...
# Train Attempt  2
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  3
# Train Attempt  1
# Train Attempt  3
# Train Attempt  3
# Train Attempt  1
# Train Attempt  1
# Training LLA3 models...
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Training LLA4 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA5 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA6 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  2
# Train Attempt  4
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA7 models...
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA8 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA9 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  3
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Training LLA10 models...
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  4
# Train Attempt  2
# Train Attempt  2
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Training LLA11 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA12 models...
# Train Attempt  2
# Train Attempt  2
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training LLA13 models...
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# done

# %%
import copy
import seaborn as sns

test_predict = strides_test[trial_types[0]][1]
min_predict = np.min(test_predict[:,1])
max_predict = np.max(test_predict[:,1])

def align_states(trained_hmm_model, roll_amount=0):
    new_hmm = copy.deepcopy(trained_hmm_model)
    array_order = np.roll(np.arange(num_states), roll_amount)

    new_hmm.model.transmat_ = new_hmm.model.transmat_[array_order,: ]
    for i, row in enumerate(new_hmm.model.transmat_):
        new_hmm.model.transmat_[i] = np.roll(new_hmm.model.transmat_[i], roll_amount)
        
    new_hmm.model.means_ = new_hmm.model.means_[array_order, :]
    new_hmm.model.covars_ = new_hmm.model.covars_[array_order, :]
    new_hmm.model.startprob_ = new_hmm.model.startprob_[array_order]
    return new_hmm 

pred_vals = np.ones(num_states)
for i in range(num_states):
    pred_vals[i] = min_predict + ((i * (max_predict - min_predict)) / (num_states - 1))

    
# roll_amounts = {'Pre': [0,3,0,0,2],
#                'PostRehab': [0,3,1,2,1],
#                'CueingRemoved': [2,2,0,1,0]}

roll_amounts = {}
match_trials = {}

for trial in trial_types:
    roll_amounts[trial] =[0 for i in range(num_models_train)]
    match_trials[trial] = 0

# roll_amounts = {'Pre': [0,0,0,0,0],
#                'PostRehab': [0,0,0,0,0],
#                'CueingRemoved': [0,0,0,0,0]}

# match_trials = {'Pre': 0,
#                'PostRehab':0,
#                'CueingRemoved':0}

shift_all = 0

def find_best_alignment(hmm_1, hmm_2, test_stride, n_states):
    min_distance = 9999999
    best_roll = 0
    
    for j in range(n_states):
        new_hmm = align_states(hmm_2, j)
        prediction_1 = hmm_1.model.predict(test_stride)
        prediction_2 = new_hmm.model.predict(test_stride)
        
        distance = np.sum((prediction_1 - prediction_2) ** 2)
        if (distance < min_distance):
            min_distance = distance
            best_roll = j
            
    return best_roll

predictions = {}
hmm_models_aligned_states = {}
for i, trial_type in enumerate(trial_types):
    predictions[trial_type] = []
    hmm_models_aligned_states[trial_type] = []
    match_trials[trial_type] = find_best_alignment(hmm_models[trial_types[0]][0], hmm_models[trial_type][0], test_predict, num_states)
    
    for j in range(num_models_train):
        roll_amounts[trial_type][j] = find_best_alignment(hmm_models[trial_type][0], hmm_models[trial_type][j], test_predict, num_states) + match_trials[trial_type]
        # roll_amounts[trial_type][j] = 0
        hmm_models_aligned_states[trial_type].append(align_states(hmm_models[trial_type][j], roll_amounts[trial_type][j] + shift_all))
        predictions[trial_type].append(hmm_models_aligned_states[trial_type][-1].model.predict(test_predict))
print(roll_amounts[trial_types[1]][0])
fig, ax = plt.subplots()
fig.set_size_inches(12,8)
plt.plot(test_predict[:,0])

plt.plot([pred_vals[j] for j in predictions[trial_types[0]][0]], 'k')
plt.plot([pred_vals[j] for j in predictions[trial_types[0]][3]], 'r')

# plt.plot([pred_vals[j] for j in predictions_post[4]], 'k')
# plt.plot([pred_vals[j] for j in predictions_post[2]], 'r')

def trial_avg_and_CI(signal_set):
    conf_int_mult = 1.00    # confidence interval multiplier for 1 std

    avg_signal = np.mean(signal_set, axis=0)
    std_signal = np.std(signal_set, axis=0)
    upper_bound = avg_signal + (conf_int_mult * std_signal)
    lower_bound = avg_signal - (conf_int_mult * std_signal)

    return avg_signal, upper_bound, lower_bound

def confidence_plot(plot_signals, fig_ax, trial_num):
    plot_signals = trial_avg_and_CI(plot_signals)
    x = np.arange(len(plot_signals[0]))
    fig_ax.plot(x, plot_signals[0], color=plot_colors[trial_num])
    fig_ax.fill_between(x, plot_signals[1], plot_signals[2], color=plot_colors[trial_num], alpha=0.2)

# confidence_plot(np.array([[pred_vals[k] for k in predictions['Pre'][j]] for j in range(5)]), ax, 0)
# confidence_plot(np.array([[pred_vals[k] for k in predictions['PostRehab'][j]] for j in range(5)]), ax, 1)
# confidence_plot(np.array([[pred_vals[k] for k in predictions['CueingRemoved'][j]] for j in range(5)]), ax, 2)

# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['Pre'][j]], 'r', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['PostRehab'][j]], 'k', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['CueingRemoved'][j]], 'b', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions_post[j]], 'r', alpha = ((j+1) / 5) * 1)

# plt.plot([pred_vals[k] for k in prediction_post], 'k')

textstr = '\n'.join((
    r'$tolerance=%.5f$' % (train_tolerance, ),
    r'$iterations=%d$' % (train_iterations, ),
    r'$states=%d$' % (num_states, )))
props = dict(boxstyle='round', facecolor='wheat', alpha=1)
ax.text(1.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.show()

print(hmm_models_aligned_states[trial_types[1]][0].model.startprob_)
print(hmm_models_aligned_states[trial_types[1]][5].model.startprob_)
# Out:
# 1
# [0. 1. 0.]
# [0. 1. 0.]

# %%
from scipy.stats import pearsonr

q_matrix = np.zeros((num_states, num_states))
div_scores = np.zeros((num_states, num_states))


def calculate_state_correspondence_matrix(hmm_1, hmm_2, n_states):
    def calculate_stationary_distribution(hmm):
        eigenvals, eigenvectors = np.linalg.eig(hmm.model.transmat_.T)
        stationary = np.array(eigenvectors[:, np.where(np.abs(eigenvals - 1.) < 1e-8)[0][0]])
        stationary = stationary / np.sum(stationary)
        return np.expand_dims(stationary.real, axis=-1)
    
    def calculate_KL_div(hmm_model_1, hmm_model_2, state_model_1, state_model_2):
        means_1 = np.expand_dims(hmm_model_1.means_[state_model_1], axis=-1)
        means_2 = np.expand_dims(hmm_model_2.means_[state_model_2], axis=-1)
        
        covars_1 = hmm_model_1.covars_[state_model_1]
        covars_2 = hmm_model_2.covars_[state_model_2]
        
        # print((means_2 - means_1).T.shape)
        # print(covars_2.shape)
        term_1 = (means_2 - means_1).T @ np.linalg.inv(covars_2) @ (means_2 - means_1)
        term_2 = np.trace(np.linalg.inv(covars_2) @ covars_1)
        term_3 = np.log(np.linalg.det(covars_1) / np.linalg.det(covars_2))
        term_4 = len(covars_1)

        kl_divergence = 0.5 * (term_1 + term_2 - term_3 - term_4)

        return kl_divergence
    
    kl_state_comparisons = np.zeros((n_states, n_states))
    pi_1 = calculate_stationary_distribution(hmm_1)
    pi_2 = calculate_stationary_distribution(hmm_2)
    total_expected_similarity = 0
    
    # print(pi_1)
    # print(pi_2)
    
    for i in range(n_states):
        for j in range(n_states):
            kl_state_comparisons[i,j] = 0.5 * (calculate_KL_div(hmm_1.model, hmm_2.model, i, j) + calculate_KL_div(hmm_2.model, hmm_1.model, i, j))
            total_expected_similarity = total_expected_similarity + (pi_1[i] * pi_2[j] * kl_state_comparisons[i,j])
    # print(total_expected_similarity)
    # print()
    k = 1
    s_e = np.exp(-k * kl_state_comparisons)
    # print(s_e)
    # print()
    s_e = 1 / kl_state_comparisons
    # print(s_e)
    # pi_1.T @ pi_2 should produce a 3x3 matrix (pi_1i * pi_2j)
    q_matrix = ((pi_1 @ pi_2.T) * s_e) / total_expected_similarity
    
    return q_matrix
    

def calculate_gini_index(q_matrix, n_states):

    def calc_gini(vector):
        vector = np.sort(vector)
        l1_norm = np.linalg.norm(vector, 1)
        a = 0
        for i in range(1, n_states+1):
            a = a + (vector[i-1] / l1_norm) * ((n_states - i + 0.5) / (n_states - 1))
        
        vec_sparsity = (n_states / (n_states - 1)) - (2 * a)
        
        return vec_sparsity
 
    r = (1 / n_states) * np.sum([calc_gini(row) for row in q_matrix])
    c = (1 / n_states) * np.sum([calc_gini(column) for column in q_matrix.T])
    
    gini_index = 0.5 * (r + c)
    return gini_index
        

# print(new_hmms[0].model.means_.shape)
# print(new_hmms[0].model.covars_.shape)
# trial_types_print = ['Avg. Sym - ' + str(np.round(np.mean(trial_syms), 3)) for trial_syms in training_symmetries]

# for i in range(len(trial_types)):
#     print()
#     for j in range(len(trial_types)):
#         sum_dif = 0
#         count = 0
#         for k in range(num_models_train):
#             if(i == j):
#                 indices = [a for a in range(num_models_train) if (not a == k)]
#             else:
#                 indices = np.arange(num_models_train)
#             for m in indices:
#                 x = calculate_state_correspondence_matrix(hmm_models_aligned_states[trial_types[i]][k], hmm_models_aligned_states[trial_types[j]][m], num_states)
#                 sum_dif = sum_dif + calculate_gini_index(x, num_states)
#                 count = count+1
        
#         mean_dif = sum_dif / count
        
#         print('%s - %s  :  %.5f' % (trial_types[i], trial_types[j], mean_dif))

gait_metric_results = {'GPS': [],
                       'HMM-SM': []}

for i in range(1, len(trial_types)):

    sum_dif = 0
    count = 0
    for k in range(num_models_train):
        for m in range(num_models_train):
            x = calculate_state_correspondence_matrix(hmm_models_aligned_states[trial_types[0]][k], hmm_models_aligned_states[trial_types[i]][m], num_states)
            sum_dif = sum_dif + calculate_gini_index(x, num_states)
            count = count+1

    mean_dif = sum_dif / count

    print('%s - %s  :  %.5f' % (trial_types[0], trial_types[i], mean_dif))
    gait_metric_results['GPS'].append(gait_metrics.calc_gait_profile_score(partitioned_gait_data[i].partitioned_movement_data, partitioned_gait_data[0].partitioned_movement_data))
    gait_metric_results['HMM-SM'].append(mean_dif)

    
plt.scatter(gait_metric_results['GPS'], gait_metric_results['HMM-SM'])
plt.xlabel('GPS Score')
plt.ylabel('HMM-SM Output')
plt.show()

corr, p_val = pearsonr(gait_metric_results['GPS'], gait_metric_results['HMM-SM'])
print('Pearsons correlation: %.3f' % corr)
print('p-value: %.4f' % p_val)
# x = calculate_state_corres

# # x = calculate_state_correspondence_matrix(hmm_models_aligned_states['Pre'][0], hmm_models_aligned_states['CueingRemoved'][4], num_states)
# y = calculate_state_correspondence_matrix(hmm_models_aligned_states['PostRehab'][0], hmm_models_aligned_states['CueingRemoved'][2], num_states)
# x_gini = calculate_gini_index(x, num_states)
# y_gini = calculate_gini_index(y, num_states)

# # y = calculate_gini_index(np.eye(4), 4)
# print(x_gini)
# print(y_gini)

# print(hmm_models[trial_types[2]][0].model.transmat_)
# Out:
# control - P01  :  0.52415
# control - AB_P02  :  0.63536
# control - AB_P04  :  0.65456
# control - AB10  :  0.52693
# control - LLA1  :  0.42697
# control - LLA2  :  0.39223
# control - LLA3  :  0.44455
# control - LLA4  :  0.58722
# control - LLA5  :  0.44426
# control - LLA6  :  0.39869
# control - LLA7  :  0.42106
# control - LLA8  :  0.35137
# control - LLA9  :  0.49269
# control - LLA10  :  0.40792
# control - LLA11  :  0.43881
# control - LLA12  :  0.34448
# control - LLA13  :  0.41437
# Pearsons correlation: -0.578
# p-value: 0.0150

# %%
from hmmlearn import hmm
import seaborn as sns

partitioned_strides = {}
for i, trial_type in enumerate(trial_types):
    # partitioned_strides[trial_type] = sym_range_strides[trial_type]['Pelvis'][:,:,3:]
    partitioned_strides[trial_type] = np.concatenate((sym_range_strides[trial_type]['UpperR'][:,:,0:], sym_range_strides[trial_type]['UpperL'][:,:,0:]), axis=2) * 0.01
    # partitioned_strides[trial_type] = np.concatenate((sym_range_strides[trial_type]['UpperR'][:,:,0:3], 
    #                                                   sym_range_strides[trial_type]['UpperL'][:,:,3:] * 0.125,
    #                                                   sym_range_strides[trial_type]['UpperR'][:,:,0:3], 
    #                                                   sym_range_strides[trial_type]['UpperL'][:,:,3:] * 0.125), axis=2)
    # print(partitioned_strides[trial_type].shape)
    np.random.shuffle(partitioned_strides[trial_type])
    print('Number of %s strides: %d' % (trial_type, len(partitioned_strides[trial_type])))
# pre_strides = partitioned_signals_dot['Pre']['LowerL'][:,:,3:]
# post_strides = partitioned_signals_dot['PostRehab']['LowerL'][:,:,3:]
# cr_strides = partitioned_signals_dot['CueingRemoved']['LowerL'][:,:,3:]
print()
# concatenate multiple strides together. Done in a "sliding window" over gait cycles, to still have reasonable amount of training samples
b20, a20 = scipy.signal.butter(N=4, Wn = 0.6, btype = 'lowpass')  # Wn = 0.2 = 10 / Nyquist F = 50Hz
concat_strides = {}
strides_to_concat = 4

# fig, axs = plt.subplots(2)
for trial_type in trial_types:
    concat_strides[trial_type] = []
    for i in range(partitioned_strides[trial_type].shape[0] - strides_to_concat):
        temp = []
        for j in range(strides_to_concat):
            temp.append(partitioned_strides[trial_type][i + j])

        concat_strides[trial_type].append(np.concatenate(temp, axis=0))
    
    concat_strides[trial_type] = np.array(concat_strides[trial_type])
    concat_strides[trial_type] = signal.filtfilt(b20, a20, concat_strides[trial_type], axis=1)
    
    # excel_reader.visualize_strides(concat_strides[trial_type][:,:,11], axs[1], 0, 0)

# plt.show()

# for i, trial_type in enumerate(trial_types):
#     print('Number of %s strides: %d' % (trial_type, len(partitioned_strides[trial_type])))

class HMMTrainer(object):
    def __init__(self, model_name='GaussianHMM', n_components=4, cov_type='full', n_iter=50, tolerance = 0.005):
        self.model_name = model_name
        self.n_components = n_components
        self.cov_type = cov_type
        self.n_iter = n_iter
        self.models = []
        if self.model_name == 'GaussianHMM':
            # self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='stmc', verbose=False)
            self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='mc', verbose=False)
            self.model.transmat_ = np.zeros((n_components, n_components))
            for i in range(n_components):
                self.model.transmat_[i, 0:2] = np.random.dirichlet(np.ones(2)/1.5, size=1)
                self.model.transmat_[i, 2:] = np.random.dirichlet(np.ones(self.n_components - 2), size=1)[0] / 1e80
                self.model.transmat_[i] = np.roll(self.model.transmat_[i], i)
            # self.model.startprob_ = np.zeros(n_components)
            # self.model.startprob_[0] = 1.0
            # self.model.transmat_ = np.zeros((n_components, n_components))
            # print(self.model.transmat_)

        else:
            raise TypeError('Invalid model type') 

    # resize_len = num_samples
    def train(self, X, resize_len, num_sequences):
        np.seterr(all='ignore')
        
        self.model.fit(X, lengths=resize_len * np.ones(num_sequences, dtype=int))
        # x_concat = np.concatenate(X).reshape(-1,1)
        # self.models.append(self.model.fit(X))
        # self.models.append(self.model.fit(x_concat, lengths = [X.shape[1] for i in range(X.shape[0])]))
        # Run the model on input data
    def get_score(self, input_data):
        return self.model.score(input_data)
        # return self.model.score(input_data.reshape(-1,1))

        

strides_train_flat = {}
strides_test_flat = {}
strides_train = {}
strides_test = {}

num_states=4
train_iterations = 300
train_tolerance = 0.01

hmm_models_l_to_r = {}

# hmm_pre_models = []
# hmm_post_models = []
# hmm_cr_models = []
num_models_train = 10

for trial_type in trial_types:
    print('Training %s models...' % (trial_type))
    hmm_models_l_to_r[trial_type] = []
    
    for j in range(num_models_train):
        train_forward_model = True
        k = 0

        while(train_forward_model):
            print('Train Attempt ', k+1, end="\r", flush=True)
            if(j > -1):
                np.random.shuffle(concat_strides[trial_type])
            strides_sequence_flattened = concat_strides[trial_type].reshape((concat_strides[trial_type].shape[0] * concat_strides[trial_type].shape[1], -1))
            len_train = int(0.95 * len(concat_strides[trial_type]))
            strides_train[trial_type] = concat_strides[trial_type][:len_train]
            strides_test[trial_type] = concat_strides[trial_type][len_train:]
            sequence_length = resize_len * strides_to_concat
            strides_train_flat[trial_type] = strides_sequence_flattened[:sequence_length * len_train]
            strides_test_flat[trial_type] = strides_sequence_flattened[sequence_length * len_train:]

            hmm_model = HMMTrainer(n_components = num_states, n_iter = train_iterations, tolerance = train_tolerance)
            hmm_model.train(strides_train_flat[trial_type], sequence_length, len_train)

            correct_second_state = [i for i in range(num_states - 1)]
            correct_second_state.append(0)
            valid_rows = 0
            for i, row in enumerate(hmm_model.model.transmat_):
                max_state = np.argmax(row)
                if(max_state == i):
                    temp = [j for j in row if not (j == row[max_state])]
                    if(np.argmax(temp) == correct_second_state[i]):
                        valid_rows = valid_rows + 1

            if(valid_rows == num_states):
                train_forward_model = False
            k = k + 1

        print()
        hmm_models_l_to_r[trial_type].append(hmm_model)

sns.heatmap(hmm_models_l_to_r[trial_types[0]][0].model.transmat_)
plt.figure()
sns.heatmap(hmm_models_l_to_r[trial_types[2]][0].model.transmat_)
# Out:
# Number of Avg. Sym - 1.043 strides: 204
# Number of Avg. Sym - 0.992 strides: 311
# Number of Avg. Sym - 0.917 strides: 147
#
# Training Avg. Sym - 1.043 models...
# Train Attempt  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31600/1402211014.py in <module>
#     117
#     118             hmm_model = HMMTrainer(n_components = num_states, n_iter = train_iterations, tolerance = train_tolerance)
# --> 119             hmm_model.train(strides_train_flat[trial_type], sequence_length, len_train)
#     120
#     121             correct_second_state = [i for i in range(num_states - 1)]
#
# /tmp/ipykernel_31600/1402211014.py in train(self, X, resize_len, num_sequences)
#      69         np.seterr(all='ignore')
#      70
# ---> 71         self.model.fit(X, lengths=resize_len * np.ones(num_sequences, dtype=int))
#      72         # x_concat = np.concatenate(X).reshape(-1,1)
#      73         # self.models.append(self.model.fit(X))
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/base.py in fit(self, X, lengths)
#     471
#     472         for iter in range(self.n_iter):
# --> 473             stats, curr_logprob = self._do_estep(X, lengths)
#     474
#     475             # Compute lower bound before updating model parameters
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/base.py in _do_estep(self, X, lengths)
#     748         curr_logprob = 0
#     749         for sub_X in _utils.split_X_lengths(X, lengths):
# --> 750             lattice, logprob, posteriors, fwdlattice, bwdlattice = impl(sub_X)
#     751             # Derived HMM classes will implement the following method to
#     752             # update their probability distributions, so keep
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/base.py in _fit_log(self, X)
#     861
#     862     def _fit_log(self, X):
# --> 863         log_frameprob = self._compute_log_likelihood(X)
#     864         log_prob, fwdlattice = _hmmc.forward_log(
#     865             self.startprob_, self.transmat_, log_frameprob)
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/_emissions.py in _compute_log_likelihood(self, X)
#     129     def _compute_log_likelihood(self, X):
#     130         return log_multivariate_normal_density(
# --> 131             X, self.means_, self._covars_, self.covariance_type)
#     132
#     133     def _initialize_sufficient_statistics(self):
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/stats.py in log_multivariate_normal_density(X, means, covars, covariance_type)
#      41         'full': _log_multivariate_normal_density_full}
#      42     return log_multivariate_normal_density_dict[covariance_type](
# ---> 43         X, means, covars
#      44     )
#      45
#
# /opt/conda/lib/python3.7/site-packages/hmmlearn/stats.py in _log_multivariate_normal_density_full(X, means, covars, min_covar)
#      91
#      92         cv_log_det = 2 * np.sum(np.log(np.diagonal(cv_chol)))
# ---> 93         cv_sol = linalg.solve_triangular(cv_chol, (X - mu).T, lower=True).T
#      94         log_prob.append(-.5 * (nf * np.log(2 * np.pi)
#      95                                + (cv_sol ** 2).sum(axis=1)
#
# /opt/conda/lib/python3.7/site-packages/scipy/linalg/basic.py in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, debug, check_finite)
#     350     if a1.flags.f_contiguous or trans == 2:
#     351         x, info = trtrs(a1, b1, overwrite_b=overwrite_b, lower=lower,
# --> 352                         trans=trans, unitdiag=unit_diagonal)
#     353     else:
#     354         # transposed system is solved since trtrs expects Fortran ordering
#
# KeyboardInterrupt:

# %%
from hmmlearn import hmm
import seaborn as sns


def shuffle_two_arrays(arr1, arr2):
    assert len(arr1) == len(arr2)
    p = np.random.permutation(len(arr1))
    return arr1[p], arr2[p]

partitioned_strides = {}
for i, trial_type in enumerate(trial_types):
    sym_train_strides = sym_range_strides[trial_type]['Pelvis'][:,:,0:]
    sym_train_strides, symmetry_split_into_ranges[i] = shuffle_two_arrays(sym_train_strides, np.array(symmetry_split_into_ranges[i]))
    # np.random.shuffle(sym_train_strides)
    
    trial_type_1 = 'Avg. Sym - ' + str( np.round( np.mean(symmetry_split_into_ranges[i][:round(len(sym_train_strides) / 2)]), 3) )
    trial_type_2 = 'Avg. Sym - ' + str( np.round( np.mean(symmetry_split_into_ranges[i][round(len(sym_train_strides) / 2):]), 3) )
    partitioned_strides[trial_type_1 + ' M1'] = sym_train_strides[:round(len(sym_train_strides) / 2)]
    partitioned_strides[trial_type_2 + ' M2'] = sym_train_strides[round(len(sym_train_strides) / 2):]
    # partitioned_strides[trial_type] = np.concatenate([sym_range_strides[trial_type]['LowerR'][:,:,0:], sym_range_strides[trial_type]['LowerL'][:,:,0:]], axis=2)
    print('Number of %s strides: %d' % (trial_type_1 + ' M1', len(partitioned_strides[trial_type_1 + ' M1'])))
    print('Number of %s strides: %d' % (trial_type_2 + ' M2', len(partitioned_strides[trial_type_2 + ' M2'])))
    
new_trial_types = partitioned_strides.keys()
# pre_strides = partitioned_signals_dot['Pre']['LowerL'][:,:,3:]
# post_strides = partitioned_signals_dot['PostRehab']['LowerL'][:,:,3:]
# cr_strides = partitioned_signals_dot['CueingRemoved']['LowerL'][:,:,3:]
print()
# concatenate multiple strides together. Done in a "sliding window" over gait cycles, to still have reasonable amount of training samples

concat_strides = {}
strides_to_concat = 4

for trial_type in new_trial_types:
    concat_strides[trial_type] = []
    for i in range(partitioned_strides[trial_type].shape[0] - strides_to_concat):
        temp = []
        for j in range(strides_to_concat):
            temp.append(partitioned_strides[trial_type][i + j])

        concat_strides[trial_type].append(np.concatenate(temp, axis=0))
    
    concat_strides[trial_type] = np.array(concat_strides[trial_type])
    concat_strides[trial_type] = signal.filtfilt(b20, a20, concat_strides[trial_type], axis=1)
    
# for i in range(pre_strides.shape[0] - strides_to_concat):
#     temp = []
#     for j in range(strides_to_concat):
#         temp.append(pre_strides[i + j])
        
#     pre_strides_concat.append(np.concatenate(temp, axis=0))
    
# for i in range(post_strides.shape[0] - strides_to_concat):
#     temp = []
#     for j in range(strides_to_concat):
#         temp.append(post_strides[i + j])
        
#     post_strides_concat.append(np.concatenate(temp, axis=0))

# pre_strides_concat = np.array(pre_strides_concat)
# post_strides_concat = np.array(post_strides_concat)


# pre_strides_concat = signal.filtfilt(b20, a20, pre_strides_concat, axis=1)
# post_strides_concat = signal.filtfilt(b20, a20, post_strides_concat, axis=1)

class HMMTrainer(object):
    def __init__(self, model_name='GaussianHMM', n_components=4, cov_type='full', n_iter=50, tolerance = 0.005):
        self.model_name = model_name
        self.n_components = n_components
        self.cov_type = cov_type
        self.n_iter = n_iter
        self.models = []
        if self.model_name == 'GaussianHMM':
            # self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='stmc', verbose=False)
            self.model = hmm.GaussianHMM(n_components=self.n_components, covariance_type=self.cov_type, n_iter=self.n_iter, tol=tolerance, params='stmc', init_params='mc', verbose=False)
            self.model.transmat_ = np.zeros((n_components, n_components))
            for i in range(n_components):
                self.model.transmat_[i, 0:2] = np.random.dirichlet(np.ones(2)/1.5, size=1)
                self.model.transmat_[i, 2:] = np.random.dirichlet(np.ones(self.n_components - 2), size=1)[0] / 1e80
                self.model.transmat_[i] = np.roll(self.model.transmat_[i], i)

        else:
            raise TypeError('Invalid model type') 

    # resize_len = num_samples
    def train(self, X, resize_len, num_sequences):
        np.seterr(all='ignore')
        
        self.model.fit(X, lengths=resize_len * np.ones(num_sequences, dtype=int))
        # x_concat = np.concatenate(X).reshape(-1,1)
        # self.models.append(self.model.fit(X))
        # self.models.append(self.model.fit(x_concat, lengths = [X.shape[1] for i in range(X.shape[0])]))
        # Run the model on input data
    def get_score(self, input_data):
        return self.model.score(input_data)
        # return self.model.score(input_data.reshape(-1,1))

strides_train_flat = {}
strides_test_flat = {}
strides_train = {}
strides_test = {}

# pre_strides_test_flat = []
# post_strides_test_flat = []
# cr_strides_test_flat = []

num_states=4
train_iterations = 300
train_tolerance = 0.01

hmm_models = {}
num_models_train = 10

for trial_type in new_trial_types:
    print('Training %s models...' % (trial_type))
    hmm_models[trial_type] = []
    
    for j in range(num_models_train):
        train_forward_model = True
        k = 0

        while(train_forward_model):
            print('Train Attempt ', k+1, end="\r", flush=True)
            if(j > -1):
                np.random.shuffle(concat_strides[trial_type])
            strides_sequence_flattened = concat_strides[trial_type].reshape((concat_strides[trial_type].shape[0] * concat_strides[trial_type].shape[1], -1))
            len_train = int(0.95 * len(concat_strides[trial_type]))
            strides_train[trial_type] = concat_strides[trial_type][:len_train]
            strides_test[trial_type] = concat_strides[trial_type][len_train:]
            sequence_length = resize_len * strides_to_concat
            strides_train_flat[trial_type] = strides_sequence_flattened[:sequence_length * len_train]
            strides_test_flat[trial_type] = strides_sequence_flattened[sequence_length * len_train:]

            hmm_model = HMMTrainer(n_components = num_states, n_iter = train_iterations, tolerance = train_tolerance)
            hmm_model.train(strides_train_flat[trial_type], sequence_length, len_train)

            correct_second_state = [i for i in range(num_states - 1)]
            correct_second_state.append(0)
            valid_rows = 0
            for i, row in enumerate(hmm_model.model.transmat_):
                max_state = np.argmax(row)
                if(max_state == i):
                    temp = [j for j in row if not (j == row[max_state])]
                    if(np.argmax(temp) == correct_second_state[i]):
                        valid_rows = valid_rows + 1

            if(valid_rows == num_states):
                train_forward_model = False
            k = k + 1

        print()
        hmm_models[trial_type].append(hmm_model)
    
print('done')
# Out:
# Number of Avg. Sym - 1.014 M1 strides: 174
# Number of Avg. Sym - 1.012 M2 strides: 173
# Number of Avg. Sym - 0.919 M1 strides: 179
# Number of Avg. Sym - 0.92 M2 strides: 179
#
# Training Avg. Sym - 1.014 M1 models...
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Training Avg. Sym - 1.012 M2 models...
# Train Attempt  1
# Train Attempt  3
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  4
# Train Attempt  1
# Train Attempt  1
# Training Avg. Sym - 0.919 M1 models...
# Train Attempt  3
# Train Attempt  2
# Train Attempt  2
# Train Attempt  3
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Training Avg. Sym - 0.92 M2 models...
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  1
# Train Attempt  1
# Train Attempt  2
# Train Attempt  1
# Train Attempt  3
# Train Attempt  1
# Train Attempt  1
# done

# %%
import copy
import seaborn as sns

new_trial_types = list(new_trial_types)

test_predict = strides_test[new_trial_types[0]][1]
min_predict = np.min(test_predict[:,1])
max_predict = np.max(test_predict[:,1])

def align_states(trained_hmm_model, roll_amount=0):
    new_hmm = copy.deepcopy(trained_hmm_model)
    array_order = np.roll(np.arange(num_states), roll_amount)

    new_hmm.model.transmat_ = new_hmm.model.transmat_[array_order,: ]
    for i, row in enumerate(new_hmm.model.transmat_):
        new_hmm.model.transmat_[i] = np.roll(new_hmm.model.transmat_[i], roll_amount)
        
    new_hmm.model.means_ = new_hmm.model.means_[array_order, :]
    new_hmm.model.covars_ = new_hmm.model.covars_[array_order, :]
    new_hmm.model.startprob_ = new_hmm.model.startprob_[array_order]
    return new_hmm 

pred_vals = np.ones(num_states)
for i in range(num_states):
    pred_vals[i] = min_predict + ((i * (max_predict - min_predict)) / (num_states - 1))

    
# roll_amounts = {'Pre': [0,3,0,0,2],
#                'PostRehab': [0,3,1,2,1],
#                'CueingRemoved': [2,2,0,1,0]}

roll_amounts = {}
match_trials = {}

for trial in new_trial_types:
    roll_amounts[trial] =[0 for i in range(num_models_train)]
    match_trials[trial] = 0

# roll_amounts = {'Pre': [0,0,0,0,0],
#                'PostRehab': [0,0,0,0,0],
#                'CueingRemoved': [0,0,0,0,0]}

# match_trials = {'Pre': 0,
#                'PostRehab':0,
#                'CueingRemoved':0}

shift_all = 0

def find_best_alignment(hmm_1, hmm_2, test_stride, n_states):
    min_distance = 9999999
    best_roll = 0
    
    for j in range(n_states):
        new_hmm = align_states(hmm_2, j)
        prediction_1 = hmm_1.model.predict(test_stride)
        prediction_2 = new_hmm.model.predict(test_stride)
        
        distance = np.sum((prediction_1 - prediction_2) ** 2)
        if (distance < min_distance):
            min_distance = distance
            best_roll = j
            
    return best_roll

predictions = {}
hmm_models_aligned_states = {}
for i, trial_type in enumerate(new_trial_types):
    predictions[trial_type] = []
    hmm_models_aligned_states[trial_type] = []
    match_trials[trial_type] = find_best_alignment(hmm_models[new_trial_types[0]][0], hmm_models[trial_type][0], test_predict, num_states)
    
    for j in range(num_models_train):
        roll_amounts[trial_type][j] = find_best_alignment(hmm_models[trial_type][0], hmm_models[trial_type][j], test_predict, num_states) + match_trials[trial_type]
        # roll_amounts[trial_type][j] = 0
        hmm_models_aligned_states[trial_type].append(align_states(hmm_models[trial_type][j], roll_amounts[trial_type][j] + shift_all))
        predictions[trial_type].append(hmm_models_aligned_states[trial_type][-1].model.predict(test_predict))
print(roll_amounts[new_trial_types[1]][0])
fig, ax = plt.subplots()
fig.set_size_inches(12,8)
plt.plot(test_predict[:,0])

plt.plot([pred_vals[j] for j in predictions[new_trial_types[0]][0]], 'k')
plt.plot([pred_vals[j] for j in predictions[new_trial_types[0]][3]], 'r')

# plt.plot([pred_vals[j] for j in predictions_post[4]], 'k')
# plt.plot([pred_vals[j] for j in predictions_post[2]], 'r')

def trial_avg_and_CI(signal_set):
    conf_int_mult = 1.00    # confidence interval multiplier for 1 std

    avg_signal = np.mean(signal_set, axis=0)
    std_signal = np.std(signal_set, axis=0)
    upper_bound = avg_signal + (conf_int_mult * std_signal)
    lower_bound = avg_signal - (conf_int_mult * std_signal)

    return avg_signal, upper_bound, lower_bound

def confidence_plot(plot_signals, fig_ax, trial_num):
    plot_signals = trial_avg_and_CI(plot_signals)
    x = np.arange(len(plot_signals[0]))
    fig_ax.plot(x, plot_signals[0], color=plot_colors[trial_num])
    fig_ax.fill_between(x, plot_signals[1], plot_signals[2], color=plot_colors[trial_num], alpha=0.2)

# confidence_plot(np.array([[pred_vals[k] for k in predictions['Pre'][j]] for j in range(5)]), ax, 0)
# confidence_plot(np.array([[pred_vals[k] for k in predictions['PostRehab'][j]] for j in range(5)]), ax, 1)
# confidence_plot(np.array([[pred_vals[k] for k in predictions['CueingRemoved'][j]] for j in range(5)]), ax, 2)

# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['Pre'][j]], 'r', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['PostRehab'][j]], 'k', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions['CueingRemoved'][j]], 'b', alpha = ((j+1) / 5) * 1)
# for j in range(5):
#     plt.plot([pred_vals[k] for k in predictions_post[j]], 'r', alpha = ((j+1) / 5) * 1)

# plt.plot([pred_vals[k] for k in prediction_post], 'k')

textstr = '\n'.join((
    r'$tolerance=%.5f$' % (train_tolerance, ),
    r'$iterations=%d$' % (train_iterations, ),
    r'$states=%d$' % (num_states, )))
props = dict(boxstyle='round', facecolor='wheat', alpha=1)
ax.text(1.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.show()




q_matrix = np.zeros((num_states, num_states))
div_scores = np.zeros((num_states, num_states))


def calculate_state_correspondence_matrix(hmm_1, hmm_2, n_states):
    def calculate_stationary_distribution(hmm):
        eigenvals, eigenvectors = np.linalg.eig(hmm.model.transmat_.T)
        stationary = np.array(eigenvectors[:, np.where(np.abs(eigenvals - 1.) < 1e-8)[0][0]])
        stationary = stationary / np.sum(stationary)
        return np.expand_dims(stationary.real, axis=-1)
    
    def calculate_KL_div(hmm_model_1, hmm_model_2, state_model_1, state_model_2):
        means_1 = np.expand_dims(hmm_model_1.means_[state_model_1], axis=-1)
        means_2 = np.expand_dims(hmm_model_2.means_[state_model_2], axis=-1)
        
        covars_1 = hmm_model_1.covars_[state_model_1]
        covars_2 = hmm_model_2.covars_[state_model_2]
        
        # print((means_2 - means_1).T.shape)
        # print(covars_2.shape)
        term_1 = (means_2 - means_1).T @ np.linalg.inv(covars_2) @ (means_2 - means_1)
        term_2 = np.trace(np.linalg.inv(covars_2) @ covars_1)
        term_3 = np.log(np.linalg.det(covars_1) / np.linalg.det(covars_2))
        term_4 = len(covars_1)

        kl_divergence = 0.5 * (term_1 + term_2 - term_3 - term_4)

        return kl_divergence
    
    kl_state_comparisons = np.zeros((n_states, n_states))
    pi_1 = calculate_stationary_distribution(hmm_1)
    pi_2 = calculate_stationary_distribution(hmm_2)
    total_expected_similarity = 0
    
    # print(pi_1)
    # print(pi_2)
    
    for i in range(n_states):
        for j in range(n_states):
            kl_state_comparisons[i,j] = 0.5 * (calculate_KL_div(hmm_1.model, hmm_2.model, i, j) + calculate_KL_div(hmm_2.model, hmm_1.model, i, j))
            total_expected_similarity = total_expected_similarity + (pi_1[i] * pi_2[j] * kl_state_comparisons[i,j])
    # print(total_expected_similarity)
    # print()
    k = 1
    s_e = np.exp(-k * kl_state_comparisons)
    # print(s_e)
    # print()
    s_e = 1 / kl_state_comparisons
    # print(s_e)
    # pi_1.T @ pi_2 should produce a 3x3 matrix (pi_1i * pi_2j)
    q_matrix = ((pi_1 @ pi_2.T) * s_e) / total_expected_similarity
    
    return q_matrix
    

def calculate_gini_index(q_matrix, n_states):

    def calc_gini(vector):
        vector = np.sort(vector)
        l1_norm = np.linalg.norm(vector, 1)
        a = 0
        for i in range(1, n_states+1):
            a = a + (vector[i-1] / l1_norm) * ((n_states - i + 0.5) / (n_states - 1))
        
        vec_sparsity = (n_states / (n_states - 1)) - (2 * a)
        
        return vec_sparsity
 
    r = (1 / n_states) * np.sum([calc_gini(row) for row in q_matrix])
    c = (1 / n_states) * np.sum([calc_gini(column) for column in q_matrix.T])
    
    gini_index = 0.5 * (r + c)
    return gini_index
        

# print(new_hmms[0].model.means_.shape)
# print(new_hmms[0].model.covars_.shape)
trial_types_print = ['Avg. Sym - ' + str(np.round(np.mean(trial_syms), 3)) for trial_syms in training_symmetries]

for i in range(len(new_trial_types)):
    print()
    for j in range(len(new_trial_types)):
        sum_dif = 0
        count = 0
        for k in range(num_models_train):
            if(i == j):
                indices = [a for a in range(num_models_train) if (not a == k)]
            else:
                indices = np.arange(num_models_train)
            for m in indices:
                x = calculate_state_correspondence_matrix(hmm_models_aligned_states[new_trial_types[i]][k], hmm_models_aligned_states[new_trial_types[j]][m], num_states)
                sum_dif = sum_dif + calculate_gini_index(x, num_states)
                count = count+1
        
        mean_dif = sum_dif / count
        
        print('%s - %s  :  %.5f' % (new_trial_types[i], new_trial_types[j], mean_dif))
# Out:
# 1
# Avg. Sym - 1.014 M1 - Avg. Sym - 1.014 M1  :  0.55446
# Avg. Sym - 1.014 M1 - Avg. Sym - 1.012 M2  :  0.55713
# Avg. Sym - 1.014 M1 - Avg. Sym - 0.919 M1  :  0.48252
# Avg. Sym - 1.014 M1 - Avg. Sym - 0.92 M2  :  0.48544
#
# Avg. Sym - 1.012 M2 - Avg. Sym - 1.014 M1  :  0.55406
# Avg. Sym - 1.012 M2 - Avg. Sym - 1.012 M2  :  0.58351
# Avg. Sym - 1.012 M2 - Avg. Sym - 0.919 M1  :  0.45300
# Avg. Sym - 1.012 M2 - Avg. Sym - 0.92 M2  :  0.47556
#
# Avg. Sym - 0.919 M1 - Avg. Sym - 1.014 M1  :  0.46094
# Avg. Sym - 0.919 M1 - Avg. Sym - 1.012 M2  :  0.42646
# Avg. Sym - 0.919 M1 - Avg. Sym - 0.919 M1  :  0.77927
# Avg. Sym - 0.919 M1 - Avg. Sym - 0.92 M2  :  0.66149
#
# Avg. Sym - 0.92 M2 - Avg. Sym - 1.014 M1  :  0.48432
# Avg. Sym - 0.92 M2 - Avg. Sym - 1.012 M2  :  0.46919
# Avg. Sym - 0.92 M2 - Avg. Sym - 0.919 M1  :  0.65401
# Avg. Sym - 0.92 M2 - Avg. Sym - 0.92 M2  :  0.61196

# %%
from sklearn.metrics import mean_squared_error as mse

def element_wise_var(array_of_matrices):
    var_array = np.zeros((array_of_matrices.shape[1], array_of_matrices.shape[2]))
    for i in range(array_of_matrices.shape[1]):
        for j in range(array_of_matrices.shape[2]):

            var_array[i,j] = np.var([x[i,j] for x in array_of_matrices])
    
    return np.mean(var_array)
            
def average_transmat_mse(mean_no_constraint_model, comparison_models):
    return np.mean([mse(mean_no_constraint_model, x) for x in comparison_models])
    
    
for trial_type in trial_types:
    norm_models = [m.model.transmat_ for m in hmm_models_aligned_states[trial_type]]
    lr_models = [m.model.transmat_ for m in hmm_models_l_to_r_aligned_states[trial_type]]
    print('Variance of transition matrices, norm (%s): ' % (trial_type), element_wise_var(np.array(norm_models)) )
    print('Variance of transition matrices, l_to_r (%s): ' % (trial_type), element_wise_var(np.array(lr_models)) )
    print()
    print('MSE of transition matrices, norm (%s): %0.5f' % (trial_type, average_transmat_mse(np.mean(norm_models, axis=0), norm_models)) )
    print('MSE of transition matrices, L to R (%s): %0.5f' % (trial_type, average_transmat_mse(np.mean(norm_models, axis=0), lr_models)) )
    print('-------------------------------------------------------------------------------------')

sns.heatmap(hmm_models_l_to_r_aligned_states[trial_types[0]][0].model.covars_[0])
plt.figure()
sns.heatmap(hmm_models_l_to_r_aligned_states[trial_types[0]][8].model.covars_[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17024/2659343377.py in <module>
#      15
#      16 for trial_type in trial_types:
# ---> 17     norm_models = [m.model.transmat_ for m in hmm_models_aligned_states[trial_type]]
#      18     lr_models = [m.model.transmat_ for m in hmm_models_l_to_r_aligned_states[trial_type]]
#      19     print('Variance of transition matrices, norm (%s): ' % (trial_type), element_wise_var(np.array(norm_models)) )
#
# KeyError: 'Avg. Sym - 1.018'

# %% [markdown]
# ######
